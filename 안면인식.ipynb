# %% [markdown]
# <a href="https://colab.research.google.com/github/ckshin29/newnewai/blob/main/%EC%95%88%EB%A9%B4%EC%9D%B8%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Client ID : rrqQxaxoR3DjFMwLrX3q
# Client Secret : tQ7JTCj9Q2

import os                # 운영체제 접근
import sys               # 시스템 접근
import requests          # 웹 접근
client_id = "rrqQxaxoR3DjFMwLrX3q"
client_secret = "tQ7JTCj9Q2"
url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
#url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식
files = {'image': open('image4.jpg', 'rb')} # 사진 파일이름
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":642,"height":642},"faceCount":2},"faces":[{"roi":{"x":239,"y":161,"width":133,"height":133},"landmark":{"leftEye":{"x":277,"y":186},"rightEye":{"x":339,"y":198},"nose":{"x":304,"y":227},"leftMouth":{"x":267,"y":259},"rightMouth":{"x":318,"y":270}},"gender":{"value":"male","confidence":0.993648},"age":{"value":"30~34","confidence":0.131165},"emotion":{"value":"neutral","confidence":0.823942},"pose":{"value":"frontal_face","confidence":0.996234}},{"roi":{"x":476,"y":319,"width":26,"height":26},"landmark":null,"gender":{"value":"male","confidence":0.800817},"age":{"value":"49~53","confidence":0.21625},"emotion":{"value":"neutral","confidence":0.53791},"pose":{"value":"rotate_face","confidence":0.674891}}]}

# %%
import json

parsed = json.loads(response.text)

type(parsed)
# Out:
# dict

# %%
print(parsed)
# Out:
# {'info': {'size': {'width': 1440, 'height': 1440}, 'faceCount': 8}, 'faces': [{'celebrity': {'value': '임강성', 'confidence': 0.277141}}, {'celebrity': {'value': '조보아', 'confidence': 0.01}}, {'celebrity': {'value': '유호정', 'confidence': 0.01}}, {'celebrity': {'value': '성훈', 'confidence': 0.01}}, {'celebrity': {'value': '유호정', 'confidence': 0.01}}, {'celebrity': {'value': '야마구치리사', 'confidence': 0.01}}, {'celebrity': {'value': '이희준', 'confidence': 0.01}}, {'celebrity': {'value': '성훈', 'confidence': 0.01}}]}

# %%
print(json.dumps(parsed, indent = 4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 642,
#             "height": 642
#         },
#         "faceCount": 2
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 239,
#                 "y": 161,
#                 "width": 133,
#                 "height": 133
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 277,
#                     "y": 186
#                 },
#                 "rightEye": {
#                     "x": 339,
#                     "y": 198
#                 },
#                 "nose": {
#                     "x": 304,
#                     "y": 227
#                 },
#                 "leftMouth": {
#                     "x": 267,
#                     "y": 259
#                 },
#                 "rightMouth": {
#                     "x": 318,
#                     "y": 270
#                 }
#             },
#             "gender": {
# ...

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(parsed['info'])
# Out:
# {'size': {'width': 642, 'height': 642}, 'faceCount': 2}

# %%
print(parsed['faces'])
# Out:
# [{'roi': {'x': 239, 'y': 161, 'width': 133, 'height': 133}, 'landmark': {'leftEye': {'x': 277, 'y': 186}, 'rightEye': {'x': 339, 'y': 198}, 'nose': {'x': 304, 'y': 227}, 'leftMouth': {'x': 267, 'y': 259}, 'rightMouth': {'x': 318, 'y': 270}}, 'gender': {'value': 'male', 'confidence': 0.993648}, 'age': {'value': '30~34', 'confidence': 0.131165}, 'emotion': {'value': 'neutral', 'confidence': 0.823942}, 'pose': {'value': 'frontal_face', 'confidence': 0.996234}}, {'roi': {'x': 476, 'y': 319, 'width': 26, 'height': 26}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.800817}, 'age': {'value': '49~53', 'confidence': 0.21625}, 'emotion': {'value': 'neutral', 'confidence': 0.53791}, 'pose': {'value': 'rotate_face', 'confidence': 0.674891}}]

# %%
parsed['faces'][0]
# Out:
# {'age': {'confidence': 0.131165, 'value': '30~34'},
#  'emotion': {'confidence': 0.823942, 'value': 'neutral'},
#  'gender': {'confidence': 0.993648, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 277, 'y': 186},
#   'leftMouth': {'x': 267, 'y': 259},
#   'nose': {'x': 304, 'y': 227},
#   'rightEye': {'x': 339, 'y': 198},
#   'rightMouth': {'x': 318, 'y': 270}},
#  'pose': {'confidence': 0.996234, 'value': 'frontal_face'},
#  'roi': {'height': 133, 'width': 133, 'x': 239, 'y': 161}}

# %%
import matplotlib.pyplot as plt # 사진 그림 관련 기본 모듈
import matplotlib.image as mpimg # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련

img = mpimg.imread('image4.jpg') # 사진 읽어오기 

fig, ax = plt.subplots() # 사진을 표시할 액자와 사진 설정
ax.imshow(img) # 액자에 사진 삽입

print(parsed['faces'][1]['roi']) 
x,y,w,h = parsed['faces'][1]['roi'].values() # 인식한 얼굴의 roi 위치 정보를 변수로 할당

re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r') # 그 위치에 사각형을 표시 정보

ax.add_patch(re_face) # 기본 사진에 사각형 정보를 올려 수정
# Out:
# {'x': 476, 'y': 319, 'width': 26, 'height': 26}

# %%
import matplotlib.pyplot as plt # 사진 그림 관련 기본 모듈
import matplotlib.image as mpimg # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련

img = mpimg.imread('image4.jpg') # 사진 읽어오기 

fig, ax = plt.subplots(figsize=(10,10)) # 사진을 표시할 액자와 사진 설정
ax.imshow(img) # 액자에 사진 삽입


for each in parsed['faces'] :

  x,y,w,h = each['roi'].values() # 인식한 얼굴의 roi 위치 정보를 변수로 할당

  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r') # 그 위치에 사각형을 표시 정보

  ax.add_patch(re_face) # 기본 사진에 사각형 정보를 올려 수정

# %%
import matplotlib.pyplot as plt          # 사진(그림) 관련 기본 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches  # 사진 수정 관련 모듈

img = mpimg.imread('image4.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 

for each in parsed['faces'] :
  x,y,w,h = each['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당
  age, age_conf = each['age'].values()
  gender, geder_conf = each['gender'].values()

  anno = gender + ',' + age

  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')  # 그 위치에 사각형을 표시 정보

  plt.text(x,y+h+20,anno,color = 'white')
  ax.add_patch(re_face)                         # 기본 사진에 사각형 정보를 올려 수정
